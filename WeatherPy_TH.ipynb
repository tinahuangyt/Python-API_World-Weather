# %% [markdown]
# # WeatherPy

# %% [markdown]
# Your objective is to build a series of scatter plots to showcase the following relationships:
#
# * Temperature (F) vs. Latitude
# * Humidity (%) vs. Latitude
# * Cloudiness (%) vs. Latitude
# * Wind Speed (mph) vs. Latitude
#
# Your final notebook must:
#
# * Randomly select **at least** 500 unique (non-repeat) cities based on latitude and longitude.
# * Perform a weather check on each of the cities using a series of successive API calls.
# * Include a print log of each city as it's being processed with the city number and city name.
# * Save both a CSV of all data retrieved and png images for each scatter plot.
#
# As final considerations:
#
# * You must complete your analysis using a Jupyter notebook.
# * You must use the Matplotlib or Pandas plotting libraries.
# * You must include a written description of three observable trends based on the data.
# * You must use proper labeling of your plots, including aspects like: Plot Titles (with date of analysis) and Axes Labels.
# * See [Example Solution](WeatherPy_Example.pdf) for a reference on expected format.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 634

# %% [markdown]
# ## Perform API calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it's being processed (with the city number and city name).

# %%
#Set up API call parameters

url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

query_url = f"{url}appid={api_key}&units={units}&q="
city = cities

#Each set will have 50 entries
x=1
y=1

city_name =[]
latitude = []
temp = []
humidity = []
cloudiness = []
windspeed = []

for city in cities:
    response = requests.get(query_url + city).json()
    try:
        city_name.append(response["name"])
        latitude.append(response["coord"]["lat"])
        temp.append(response["main"]["temp"])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        windspeed.append(response["wind"]["speed"])
        print(f"Processing record number {x} of set {y} | {city}")
        if x>49:
            x=1
            y=y+1
        else:
            x=x+1
    except:
        print(f"City not found, next..")
# Out:
# Processing record number 1 of set 1 | fairview
# Processing record number 2 of set 1 | bonavista
# Processing record number 3 of set 1 | kapaa
# Processing record number 4 of set 1 | nikolskoye
# Processing record number 5 of set 1 | rio grande
# Processing record number 6 of set 1 | lebu
# Processing record number 7 of set 1 | west fargo
# Processing record number 8 of set 1 | hermanus
# Processing record number 9 of set 1 | manta
# Processing record number 10 of set 1 | vaini
# Processing record number 11 of set 1 | nanortalik
# Processing record number 12 of set 1 | wanning
# Processing record number 13 of set 1 | banda aceh
# Processing record number 14 of set 1 | mahebourg
# Processing record number 15 of set 1 | paita
# Processing record number 16 of set 1 | tuktoyaktuk
# Processing record number 17 of set 1 | san patricio
# Processing record number 18 of set 1 | qaanaaq
# Processing record number 19 of set 1 | mataura
# Processing record number 20 of set 1 | dingle
# Processing record number 21 of set 1 | yar-sale
# Processing record number 22 of set 1 | chapais
# Processing record number 23 of set 1 | vila velha
# Processing record number 24 of set 1 | tromso
# Processing record number 25 of set 1 | jamestown
# City not found, next..
# Processing record number 26 of set 1 | ushuaia
# Processing record number 27 of set 1 | busselton
# Processing record number 28 of set 1 | pontianak
# Processing record number 29 of set 1 | porto novo
# Processing record number 30 of set 1 | pevek
# Processing record number 31 of set 1 | saint-philippe
# Processing record number 32 of set 1 | punta arenas
# Processing record number 33 of set 1 | atuona
# Processing record number 34 of set 1 | abashiri
# City not found, next..
# Processing record number 35 of set 1 | sovetskaya gavan
# Processing record number 36 of set 1 | usinsk
# Processing record number 37 of set 1 | lumeje
# Processing record number 38 of set 1 | port elizabeth
# Processing record number 39 of set 1 | ossora
# Processing record number 40 of set 1 | port alfred
# Processing record number 41 of set 1 | bredasdorp
# Processing record number 42 of set 1 | thompson
# Processing record number 43 of set 1 | issenye
# Processing record number 44 of set 1 | port blair
# Processing record number 45 of set 1 | huarmey
# City not found, next..
# Processing record number 46 of set 1 | meulaboh
# Processing record number 47 of set 1 | alugan
# Processing record number 48 of set 1 | new norfolk
# Processing record number 49 of set 1 | barrow
# Processing record number 50 of set 1 | urucui
# Processing record number 1 of set 2 | albany
# Processing record number 2 of set 2 | tortoli
# Processing record number 3 of set 2 | zhongshu
# Processing record number 4 of set 2 | ahipara
# Processing record number 5 of set 2 | aykhal
# Processing record number 6 of set 2 | kiunga
# Processing record number 7 of set 2 | la asuncion
# Processing record number 8 of set 2 | innisfail
# Processing record number 9 of set 2 | santiago
# Processing record number 10 of set 2 | hasaki
# Processing record number 11 of set 2 | dunmore town
# Processing record number 12 of set 2 | carnarvon
# City not found, next..
# Processing record number 13 of set 2 | kaitangata
# City not found, next..
# Processing record number 14 of set 2 | los llanos de aridane
# Processing record number 15 of set 2 | jutai
# Processing record number 16 of set 2 | strelka
# Processing record number 17 of set 2 | tezu
# Processing record number 18 of set 2 | satun
# City not found, next..
# Processing record number 19 of set 2 | lakselv
# Processing record number 20 of set 2 | bosanska kostajnica
# Processing record number 21 of set 2 | rikitea
# Processing record number 22 of set 2 | sao filipe
# Processing record number 23 of set 2 | hirado
# City not found, next..
# Processing record number 24 of set 2 | pimentel
# Processing record number 25 of set 2 | byron bay
# Processing record number 26 of set 2 | cabo san lucas
# Processing record number 27 of set 2 | laguna
# Processing record number 28 of set 2 | pizarro
# Processing record number 29 of set 2 | cape town
# Processing record number 30 of set 2 | phan thiet
# Processing record number 31 of set 2 | dunkirk
# Processing record number 32 of set 2 | leningradskiy
# City not found, next..
# Processing record number 33 of set 2 | bluff
# Processing record number 34 of set 2 | gilbues
# Processing record number 35 of set 2 | victoria
# Processing record number 36 of set 2 | cherskiy
# Processing record number 37 of set 2 | general roca
# Processing record number 38 of set 2 | srednekolymsk
# Processing record number 39 of set 2 | tiksi
# City not found, next..
# Processing record number 40 of set 2 | avarua
# Processing record number 41 of set 2 | tselinnoye
# Processing record number 42 of set 2 | butaritari
# Processing record number 43 of set 2 | baculin
# Processing record number 44 of set 2 | ostrovnoy
# Processing record number 45 of set 2 | waddan
# Processing record number 46 of set 2 | margate
# Processing record number 47 of set 2 | norman wells
# Processing record number 48 of set 2 | kaspiysk
# Processing record number 49 of set 2 | kathu
# Processing record number 50 of set 2 | karratha
# Processing record number 1 of set 3 | erbaa
# Processing record number 2 of set 3 | portland
# Processing record number 3 of set 3 | grimshaw
# City not found, next..
# City not found, next..
# Processing record number 4 of set 3 | trincomalee
# Processing record number 5 of set 3 | kahului
# Processing record number 6 of set 3 | khatanga
# Processing record number 7 of set 3 | rolla
# Processing record number 8 of set 3 | biak
# Processing record number 9 of set 3 | hilo
# Processing record number 10 of set 3 | kununurra
# Processing record number 11 of set 3 | tsumeb
# Processing record number 12 of set 3 | hami
# Processing record number 13 of set 3 | damghan
# Processing record number 14 of set 3 | puerto ayora
# Processing record number 15 of set 3 | belem de sao francisco
# Processing record number 16 of set 3 | te anau
# Processing record number 17 of set 3 | cidreira
# Processing record number 18 of set 3 | aketi
# Processing record number 19 of set 3 | faanui
# Processing record number 20 of set 3 | wenling
# City not found, next..
# Processing record number 21 of set 3 | nome
# Processing record number 22 of set 3 | vao
# Processing record number 23 of set 3 | kargasok
# Processing record number 24 of set 3 | fort nelson
# Processing record number 25 of set 3 | arraial do cabo
# Processing record number 26 of set 3 | anshan
# City not found, next..
# Processing record number 27 of set 3 | am timan
# Processing record number 28 of set 3 | coquimbo
# Processing record number 29 of set 3 | takoradi
# Processing record number 30 of set 3 | karoi
# Processing record number 31 of set 3 | yarada
# Processing record number 32 of set 3 | barabinsk
# Processing record number 33 of set 3 | dudinka
# Processing record number 34 of set 3 | amahai
# Processing record number 35 of set 3 | ribeira grande
# Processing record number 36 of set 3 | dikson
# Processing record number 37 of set 3 | bethel
# Processing record number 38 of set 3 | roma
# Processing record number 39 of set 3 | souillac
# Processing record number 40 of set 3 | sainte-maxime
# Processing record number 41 of set 3 | okhotsk
# Processing record number 42 of set 3 | arman
# Processing record number 43 of set 3 | camacha
# Processing record number 44 of set 3 | adrar
# Processing record number 45 of set 3 | ardabil
# Processing record number 46 of set 3 | tarakan
# Processing record number 47 of set 3 | sayan
# Processing record number 48 of set 3 | castro
# Processing record number 49 of set 3 | zabol
# Processing record number 50 of set 3 | qaqortoq
# Processing record number 1 of set 4 | chokurdakh
# City not found, next..
# City not found, next..
# Processing record number 2 of set 4 | gigmoto
# Processing record number 3 of set 4 | inirida
# City not found, next..
# Processing record number 4 of set 4 | bosaso
# Processing record number 5 of set 4 | sorland
# Processing record number 6 of set 4 | hobart
# Processing record number 7 of set 4 | longyearbyen
# Processing record number 8 of set 4 | mainit
# Processing record number 9 of set 4 | waingapu
# Processing record number 10 of set 4 | mount gambier
# Processing record number 11 of set 4 | storsteinnes
# Processing record number 12 of set 4 | hithadhoo
# Processing record number 13 of set 4 | ponta do sol
# Processing record number 14 of set 4 | provideniya
# Processing record number 15 of set 4 | huilong
# Processing record number 16 of set 4 | havoysund
# Processing record number 17 of set 4 | kavieng
# Processing record number 18 of set 4 | bathsheba
# Processing record number 19 of set 4 | vilyuysk
# Processing record number 20 of set 4 | middelburg
# Processing record number 21 of set 4 | yarmouth
# Processing record number 22 of set 4 | kruisfontein
# City not found, next..
# Processing record number 23 of set 4 | popondetta
# Processing record number 24 of set 4 | mangochi
# Processing record number 25 of set 4 | tura
# Processing record number 26 of set 4 | chuy
# Processing record number 27 of set 4 | saint george
# Processing record number 28 of set 4 | saldanha
# Processing record number 29 of set 4 | severo-kurilsk
# Processing record number 30 of set 4 | naze
# Processing record number 31 of set 4 | east london
# Processing record number 32 of set 4 | lagoa
# Processing record number 33 of set 4 | ketchikan
# Processing record number 34 of set 4 | mehriz
# Processing record number 35 of set 4 | cape canaveral
# Processing record number 36 of set 4 | hamilton
# Processing record number 37 of set 4 | kirakira
# City not found, next..
# Processing record number 38 of set 4 | carauari
# Processing record number 39 of set 4 | port macquarie
# Processing record number 40 of set 4 | tuka
# Processing record number 41 of set 4 | port hedland
# Processing record number 42 of set 4 | mar del plata
# City not found, next..
# Processing record number 43 of set 4 | plainview
# Processing record number 44 of set 4 | luderitz
# Processing record number 45 of set 4 | tasiilaq
# Processing record number 46 of set 4 | holzkirchen
# Processing record number 47 of set 4 | conde
# City not found, next..
# Processing record number 48 of set 4 | yellowknife
# City not found, next..
# Processing record number 49 of set 4 | celestun
# Processing record number 50 of set 4 | iberia
# Processing record number 1 of set 5 | rongcheng
# Processing record number 2 of set 5 | khorixas
# Processing record number 3 of set 5 | lorengau
# Processing record number 4 of set 5 | tokur
# Processing record number 5 of set 5 | miguel hidalgo
# Processing record number 6 of set 5 | katsuura
# City not found, next..
# Processing record number 7 of set 5 | mantua
# City not found, next..
# Processing record number 8 of set 5 | toba tek singh
# Processing record number 9 of set 5 | nacogdoches
# Processing record number 10 of set 5 | cotonou
# Processing record number 11 of set 5 | san quintin
# Processing record number 12 of set 5 | manokwari
# Processing record number 13 of set 5 | mufulira
# Processing record number 14 of set 5 | wloclawek
# Processing record number 15 of set 5 | rancho palos verdes
# Processing record number 16 of set 5 | nishihara
# Processing record number 17 of set 5 | sola
# Processing record number 18 of set 5 | thinadhoo
# City not found, next..
# Processing record number 19 of set 5 | salalah
# Processing record number 20 of set 5 | shizunai
# City not found, next..
# Processing record number 21 of set 5 | tuatapere
# Processing record number 22 of set 5 | herzogenaurach
# Processing record number 23 of set 5 | paamiut
# Processing record number 24 of set 5 | rundu
# Processing record number 25 of set 5 | luau
# Processing record number 26 of set 5 | lipin bor
# Processing record number 27 of set 5 | tahlequah
# Processing record number 28 of set 5 | sangar
# Processing record number 29 of set 5 | pallisa
# Processing record number 30 of set 5 | henderson
# Processing record number 31 of set 5 | hudiksvall
# Processing record number 32 of set 5 | mehran
# Processing record number 33 of set 5 | namibe
# Processing record number 34 of set 5 | college
# City not found, next..
# Processing record number 35 of set 5 | tungor
# Processing record number 36 of set 5 | sobolevo
# Processing record number 37 of set 5 | roura
# Processing record number 38 of set 5 | chiredzi
# Processing record number 39 of set 5 | saskylakh
# Processing record number 40 of set 5 | constitucion
# Processing record number 41 of set 5 | port lincoln
# Processing record number 42 of set 5 | okha
# Processing record number 43 of set 5 | padang
# Processing record number 44 of set 5 | upernavik
# Processing record number 45 of set 5 | mae hong son
# City not found, next..
# Processing record number 46 of set 5 | alta floresta
# Processing record number 47 of set 5 | sarai alamgir
# City not found, next..
# City not found, next..
# Processing record number 48 of set 5 | pattani
# Processing record number 49 of set 5 | handan
# Processing record number 50 of set 5 | dogondoutchi
# Processing record number 1 of set 6 | abha
# Processing record number 2 of set 6 | el alto
# Processing record number 3 of set 6 | vila
# Processing record number 4 of set 6 | narrabri
# Processing record number 5 of set 6 | isangel
# Processing record number 6 of set 6 | aksu
# Processing record number 7 of set 6 | locri
# Processing record number 8 of set 6 | santa luzia
# Processing record number 9 of set 6 | finspang
# Processing record number 10 of set 6 | nelson bay
# Processing record number 11 of set 6 | tagusao
# Processing record number 12 of set 6 | aripuana
# Processing record number 13 of set 6 | tecoanapa
# Processing record number 14 of set 6 | ranau
# Processing record number 15 of set 6 | narsaq
# Processing record number 16 of set 6 | abu kamal
# Processing record number 17 of set 6 | hambantota
# Processing record number 18 of set 6 | torbay
# Processing record number 19 of set 6 | oranjemund
# Processing record number 20 of set 6 | sao felix do xingu
# Processing record number 21 of set 6 | geraldton
# Processing record number 22 of set 6 | ponta delgada
# Processing record number 23 of set 6 | namatanai
# Processing record number 24 of set 6 | usakos
# Processing record number 25 of set 6 | nieuw amsterdam
# Processing record number 26 of set 6 | gold coast
# Processing record number 27 of set 6 | san luis
# Processing record number 28 of set 6 | quatre cocos
# Processing record number 29 of set 6 | santa rosa
# City not found, next..
# City not found, next..
# Processing record number 30 of set 6 | muros
# Processing record number 31 of set 6 | road town
# Processing record number 32 of set 6 | pingliang
# City not found, next..
# Processing record number 33 of set 6 | yeppoon
# Processing record number 34 of set 6 | pemba
# City not found, next..
# Processing record number 35 of set 6 | winchester
# Processing record number 36 of set 6 | grand gaube
# Processing record number 37 of set 6 | paracatu
# Processing record number 38 of set 6 | necochea
# Processing record number 39 of set 6 | bowen
# Processing record number 40 of set 6 | gisborne
# Processing record number 41 of set 6 | ilulissat
# Processing record number 42 of set 6 | penzance
# Processing record number 43 of set 6 | colares
# City not found, next..
# Processing record number 44 of set 6 | huaraz
# Processing record number 45 of set 6 | oloron-sainte-marie
# Processing record number 46 of set 6 | tole
# Processing record number 47 of set 6 | trindade
# Processing record number 48 of set 6 | kindia
# Processing record number 49 of set 6 | rincon
# Processing record number 50 of set 6 | kishanpur
# Processing record number 1 of set 7 | port moresby
# Processing record number 2 of set 7 | kilindoni
# Processing record number 3 of set 7 | dubrovnik
# Processing record number 4 of set 7 | jalu
# Processing record number 5 of set 7 | gorontalo
# Processing record number 6 of set 7 | broken hill
# Processing record number 7 of set 7 | kailua
# Processing record number 8 of set 7 | berlevag
# Processing record number 9 of set 7 | belyy yar
# Processing record number 10 of set 7 | madimba
# Processing record number 11 of set 7 | moscow
# Processing record number 12 of set 7 | leshukonskoye
# Processing record number 13 of set 7 | broome
# City not found, next..
# Processing record number 14 of set 7 | kulhudhuffushi
# Processing record number 15 of set 7 | morales
# Processing record number 16 of set 7 | burley
# Processing record number 17 of set 7 | atyrau
# Processing record number 18 of set 7 | sideropolis
# Processing record number 19 of set 7 | boa vista
# Processing record number 20 of set 7 | villa union
# Processing record number 21 of set 7 | lompoc
# Processing record number 22 of set 7 | klaksvik
# Processing record number 23 of set 7 | alihe
# Processing record number 24 of set 7 | canjulao
# Processing record number 25 of set 7 | nhulunbuy
# Processing record number 26 of set 7 | qandala
# Processing record number 27 of set 7 | tuy hoa
# Processing record number 28 of set 7 | deputatskiy
# Processing record number 29 of set 7 | mogadishu
# Processing record number 30 of set 7 | smithers
# Processing record number 31 of set 7 | bartica
# Processing record number 32 of set 7 | trelew
# Processing record number 33 of set 7 | kyshtovka
# Processing record number 34 of set 7 | cartagena
# Processing record number 35 of set 7 | dalby
# Processing record number 36 of set 7 | ambilobe
# Processing record number 37 of set 7 | fairbanks
# Processing record number 38 of set 7 | iskateley
# Processing record number 39 of set 7 | inverell
# Processing record number 40 of set 7 | jacksonville
# Processing record number 41 of set 7 | matagami
# Processing record number 42 of set 7 | glendive
# Processing record number 43 of set 7 | tautira
# Processing record number 44 of set 7 | georgetown
# City not found, next..
# Processing record number 45 of set 7 | guerrero negro
# Processing record number 46 of set 7 | verkhnevilyuysk
# Processing record number 47 of set 7 | numan
# Processing record number 48 of set 7 | wufeng
# Processing record number 49 of set 7 | pangnirtung
# City not found, next..
# Processing record number 50 of set 7 | taiobeiras
# Processing record number 1 of set 8 | champerico
# Processing record number 2 of set 8 | fortuna
# Processing record number 3 of set 8 | praia da vitoria
# Processing record number 4 of set 8 | bourail
# Processing record number 5 of set 8 | vestmannaeyjar
# Processing record number 6 of set 8 | alamosa
# Processing record number 7 of set 8 | ullapool
# City not found, next..
# City not found, next..
# Processing record number 8 of set 8 | shellbrook
# Processing record number 9 of set 8 | mosquera
# Processing record number 10 of set 8 | papillion
# Processing record number 11 of set 8 | codrington
# Processing record number 12 of set 8 | rocha
# Processing record number 13 of set 8 | ucluelet
# Processing record number 14 of set 8 | mackay
# Processing record number 15 of set 8 | inhambane
# Processing record number 16 of set 8 | acapulco
# Processing record number 17 of set 8 | cullman
# Processing record number 18 of set 8 | kodiak
# Processing record number 19 of set 8 | horta
# Processing record number 20 of set 8 | dinant
# Processing record number 21 of set 8 | karymskoye
# Processing record number 22 of set 8 | ulladulla
# Processing record number 23 of set 8 | la ronge
# Processing record number 24 of set 8 | la poza
# Processing record number 25 of set 8 | mao
# Processing record number 26 of set 8 | felanitx
# Processing record number 27 of set 8 | kutum
# Processing record number 28 of set 8 | ridgecrest
# Processing record number 29 of set 8 | henties bay
# City not found, next..
# Processing record number 30 of set 8 | bonthe
# Processing record number 31 of set 8 | kysyl-syr
# Processing record number 32 of set 8 | hobyo
# Processing record number 33 of set 8 | anadyr
# City not found, next..
# Processing record number 34 of set 8 | dumalaguing
# City not found, next..
# Processing record number 35 of set 8 | kenai
# Processing record number 36 of set 8 | misratah
# Processing record number 37 of set 8 | glyadyanskoye
# City not found, next..
# Processing record number 38 of set 8 | touros
# Processing record number 39 of set 8 | evensk
# Processing record number 40 of set 8 | mananjary
# Processing record number 41 of set 8 | imphal
# Processing record number 42 of set 8 | opuwo
# Processing record number 43 of set 8 | oneida
# Processing record number 44 of set 8 | constantine
# Processing record number 45 of set 8 | olinda
# Processing record number 46 of set 8 | andros town
# Processing record number 47 of set 8 | caravelas
# Processing record number 48 of set 8 | clyde river
# City not found, next..
# Processing record number 49 of set 8 | umm lajj
# Processing record number 50 of set 8 | tornesch
# Processing record number 1 of set 9 | tuim
# Processing record number 2 of set 9 | ibra
# Processing record number 3 of set 9 | saint-augustin
# Processing record number 4 of set 9 | kupang
# Processing record number 5 of set 9 | bambous virieux
# Processing record number 6 of set 9 | eyl
# Processing record number 7 of set 9 | raudeberg
# Processing record number 8 of set 9 | marawi
# Processing record number 9 of set 9 | puerto palomas
# Processing record number 10 of set 9 | borogontsy
# Processing record number 11 of set 9 | zharkent
# Processing record number 12 of set 9 | derzhavinsk
# Processing record number 13 of set 9 | masterton
# City not found, next..
# Processing record number 14 of set 9 | vikulovo
# Processing record number 15 of set 9 | kerchevskiy
# Processing record number 16 of set 9 | buluang
# Processing record number 17 of set 9 | haines junction
# Processing record number 18 of set 9 | pingshan
# Processing record number 19 of set 9 | kolondieba
# Processing record number 20 of set 9 | farsund
# Processing record number 21 of set 9 | panzhihua
# Processing record number 22 of set 9 | vanimo
# Processing record number 23 of set 9 | dukat
# Processing record number 24 of set 9 | mardin
# Processing record number 25 of set 9 | halifax
# Processing record number 26 of set 9 | ponca city
# Processing record number 27 of set 9 | fuxin
# Processing record number 28 of set 9 | axim
# City not found, next..
# City not found, next..
# Processing record number 29 of set 9 | saint-pierre
# Processing record number 30 of set 9 | dickinson
# Processing record number 31 of set 9 | mahina
# Processing record number 32 of set 9 | bol
# Processing record number 33 of set 9 | dandong
# Processing record number 34 of set 9 | salto
# Processing record number 35 of set 9 | darya khan
# Processing record number 36 of set 9 | cazones
# Processing record number 37 of set 9 | ribeirao
# Processing record number 38 of set 9 | tororo
# Processing record number 39 of set 9 | clarence town
# Processing record number 40 of set 9 | plettenberg bay
# Processing record number 41 of set 9 | ghanzi
# Processing record number 42 of set 9 | kasongo-lunda
# Processing record number 43 of set 9 | husavik
# Processing record number 44 of set 9 | ewo
# Processing record number 45 of set 9 | punta cardon
# Processing record number 46 of set 9 | vardo
# Processing record number 47 of set 9 | orange
# Processing record number 48 of set 9 | mahibadhoo
# Processing record number 49 of set 9 | gull lake
# Processing record number 50 of set 9 | mendi
# Processing record number 1 of set 10 | ahualulco
# Processing record number 2 of set 10 | yuncheng
# Processing record number 3 of set 10 | eenhana
# Processing record number 4 of set 10 | ibanda
# Processing record number 5 of set 10 | taltal
# Processing record number 6 of set 10 | chumikan
# Processing record number 7 of set 10 | pangody
# City not found, next..
# Processing record number 8 of set 10 | labuhan
# Processing record number 9 of set 10 | ternate
# Processing record number 10 of set 10 | port hardy
# Processing record number 11 of set 10 | mwinilunga
# Processing record number 12 of set 10 | ayan
# Processing record number 13 of set 10 | lasa
# Processing record number 14 of set 10 | liwale
# Processing record number 15 of set 10 | carupano
# Processing record number 16 of set 10 | omsukchan
# City not found, next..
# Processing record number 17 of set 10 | aksarka
# Processing record number 18 of set 10 | kawalu
# Processing record number 19 of set 10 | beringovskiy
# City not found, next..
# Processing record number 20 of set 10 | yulara
# Processing record number 21 of set 10 | arawa
# City not found, next..
# Processing record number 22 of set 10 | mokhsogollokh
# Processing record number 23 of set 10 | aleysk
# Processing record number 24 of set 10 | deep river
# Processing record number 25 of set 10 | pilas
# Processing record number 26 of set 10 | bereda
# Processing record number 27 of set 10 | northam
# Processing record number 28 of set 10 | santa cruz do rio pardo
# Processing record number 29 of set 10 | kon tum
# Processing record number 30 of set 10 | maniitsoq
# Processing record number 31 of set 10 | tilichiki
# Processing record number 32 of set 10 | marzuq
# Processing record number 33 of set 10 | lebork
# Processing record number 34 of set 10 | gbarnga
# Processing record number 35 of set 10 | bemidji
# Processing record number 36 of set 10 | grants pass
# Processing record number 37 of set 10 | gamba
# Processing record number 38 of set 10 | pierre
# Processing record number 39 of set 10 | brigantine
# Processing record number 40 of set 10 | goundi
# Processing record number 41 of set 10 | calvinia
# City not found, next..
# Processing record number 42 of set 10 | itarema
# Processing record number 43 of set 10 | cortez
# Processing record number 44 of set 10 | miraflores
# Processing record number 45 of set 10 | sitka
# Processing record number 46 of set 10 | half moon bay
# Processing record number 47 of set 10 | bulaevo
# Processing record number 48 of set 10 | tual
# Processing record number 49 of set 10 | kalmunai
# Processing record number 50 of set 10 | sulecin
# Processing record number 1 of set 11 | badiraguato
# Processing record number 2 of set 11 | muskegon
# Processing record number 3 of set 11 | klyuchi
# Processing record number 4 of set 11 | leh
# Processing record number 5 of set 11 | tabou
# Processing record number 6 of set 11 | tommot
# Processing record number 7 of set 11 | liverpool
# Processing record number 8 of set 11 | wheeling
# City not found, next..
# Processing record number 9 of set 11 | cassilandia
# Processing record number 10 of set 11 | sibolga
# Processing record number 11 of set 11 | gulaothi
# Processing record number 12 of set 11 | turukhansk
# Processing record number 13 of set 11 | hassleholm
# Processing record number 14 of set 11 | hendek
# Processing record number 15 of set 11 | kieta
# Processing record number 16 of set 11 | otavi
# Processing record number 17 of set 11 | guozhen
# Processing record number 18 of set 11 | canguaretama
# City not found, next..
# Processing record number 19 of set 11 | nemuro
# City not found, next..
# Processing record number 20 of set 11 | talnakh
# Processing record number 21 of set 11 | socorro
# Processing record number 22 of set 11 | murray bridge
# City not found, next..
# Processing record number 23 of set 11 | leresti
# Processing record number 24 of set 11 | goderich
# Processing record number 25 of set 11 | ulsteinvik
# Processing record number 26 of set 11 | vagur
# Processing record number 27 of set 11 | jaru
# City not found, next..
# Processing record number 28 of set 11 | yerbogachen
# Processing record number 29 of set 11 | taloqan
# Processing record number 30 of set 11 | flinders
# Processing record number 31 of set 11 | borgarnes
# Processing record number 32 of set 11 | kushiro
# Processing record number 33 of set 11 | lata
# Processing record number 34 of set 11 | jorpeland
# Processing record number 35 of set 11 | koungheul
# City not found, next..
# Processing record number 36 of set 11 | longkou
# Processing record number 37 of set 11 | vestmanna
# Processing record number 38 of set 11 | itoman
# Processing record number 39 of set 11 | tombouctou
# Processing record number 40 of set 11 | juneau
# Processing record number 41 of set 11 | segezha
# Processing record number 42 of set 11 | san miguel de cauri
# City not found, next..
# City not found, next..
# City not found, next..
# Processing record number 43 of set 11 | ganta
# Processing record number 44 of set 11 | calama
# Processing record number 45 of set 11 | zabaykalsk
# Processing record number 46 of set 11 | cervo
# City not found, next..
# Processing record number 47 of set 11 | ust-kulom
# Processing record number 48 of set 11 | camopi
# Processing record number 49 of set 11 | naantali
# Processing record number 50 of set 11 | alberton
# Processing record number 1 of set 12 | mitu
# Processing record number 2 of set 12 | pisco
# Processing record number 3 of set 12 | sadiqabad
# Processing record number 4 of set 12 | esperance
# Processing record number 5 of set 12 | san vicente
# Processing record number 6 of set 12 | pasir mas
# Processing record number 7 of set 12 | spornoye
# Processing record number 8 of set 12 | okato
# Processing record number 9 of set 12 | biu
# City not found, next..
# Processing record number 10 of set 12 | jacqueville
# Processing record number 11 of set 12 | garchitorena
# Processing record number 12 of set 12 | kyaikkami
# City not found, next..
# Processing record number 13 of set 12 | slyudyanka
# City not found, next..
# Processing record number 14 of set 12 | coahuayana
# Processing record number 15 of set 12 | valparaiso
# Processing record number 16 of set 12 | tumpat
# City not found, next..
# Processing record number 17 of set 12 | esil
# Processing record number 18 of set 12 | bonanza

# %%
#Combine all lists to generate CSV file
combined_list = list(zip(city_name, latitude, temp, humidity, cloudiness, windspeed))

#Export to CSV
import csv
myfile = open("world_weather_info.csv",'w')
with myfile:
    header = ["City", "Latitude", "Temp (F)","Humidity", "Cloudiness", "Windspeed (mph)"]
    writer= csv.writer(myfile)
    writer.writerows(combined_list)

# %%
#Create a df for all the retrieved data
world_weather = pd.DataFrame(columns=["City", "Latitude", "Temp (F)","Humidity", "Cloudiness", "Windspeed (mph)"])
world_weather["City"]=city_name
world_weather["Latitude"]=latitude
world_weather["Temp (F)"]=temp
world_weather["Humidity"]=humidity
world_weather["Cloudiness"]=cloudiness
world_weather["Windspeed (mph)"]=windspeed

world_weather.head()
# Out:
#          City  Latitude  Temp (F)  Humidity  Cloudiness  Windspeed (mph)
# 0    Fairview     40.81     41.04        30           1             3.65
# 1   Bonavista     48.65     30.00        57           0            21.99
# 2       Kapaa     22.08     65.97        64          90             8.05
# 3  Nikolskoye     59.70     37.85        86          90             6.71
# 4  Rio Grande    -32.03     71.60        94          90            13.87

# %%
world_weather.count()
# Out:
# City               568
# Latitude           568
# Temp (F)           568
# Humidity           568
# Cloudiness         568
# Windspeed (mph)    568
# dtype: int64

# %% [markdown]
# ## Plotting the Data
#
# * Temperature (F) vs. Latitude
# * Humidity (%) vs. Latitude
# * Cloudiness (%) vs. Latitude
# * Wind Speed (mph) vs. Latitude
